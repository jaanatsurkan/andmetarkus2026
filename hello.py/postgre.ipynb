# %% [markdown]
# # Postgre baasist andmete pärimine

# %%
# !pip3 install psycopg2-binary

# %%
import pandas as pd
import psycopg2

# %%
conn = psycopg2.connect(
    host="localhost",
    database="cafe",
    user="postgres",
    password="160992"
)

df.pd.read_sql("SELECT 1")
